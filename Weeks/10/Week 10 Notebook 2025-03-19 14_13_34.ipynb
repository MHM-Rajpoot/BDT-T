# %%
# %sh
pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-59c213d1-1a8e-40ca-a360-02b1320fc7be/bin/python -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)
fig, ax=plt. subplots ()
ax.plot(x, y)
plt.show()

# %%
plt.style.use('_mpl-gallery')

x = np.arange(0, 10, 2)
ay = [1, 1.2, 2, 2.7, 3]
by = [3, 2, 1, 2, 2]
cy = [2, 3, 2, 1, 4]

y = np.vstack([ay, by, cy])

fig, ax = plt. subplots()
ax.stackplot(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
ylim=(0, 8), yticks=np.arange(1, 10))
plt.show()

# %%
plt.style. use('_mpl-gallery')

np.random.seed(10)

n = 100
rng = np. random.default_rng()

xs = rng.uniform(55, 95, n)
ys = rng. uniform(0, 300, n)
zs = rng.uniform(-50, 0, n)

fig, ax = plt. subplots(subplot_kw={"projection": "3d"})
ax.scatter(xs, ys, zs)
plt.show()

# %%
plt.style.use('_mpl-gallery')

np.random.seed(3)
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

fig, ax = plt. subplots()
ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()

# %%
dbutils.fs.ls("dbfs:/databricks-datasets/")
# Out:
# Out[6]: [FileInfo(path='dbfs:/databricks-datasets/COVID/', name='COVID/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/README.md', name='README.md', size=976, modificationTime=1532468253000),
#  FileInfo(path='dbfs:/databricks-datasets/Rdatasets/', name='Rdatasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/SPARK_README.md', name='SPARK_README.md', size=3359, modificationTime=1455043490000),
#  FileInfo(path='dbfs:/databricks-datasets/adult/', name='adult/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/airlines/', name='airlines/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/amazon/', name='amazon/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/asa/', name='asa/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/atlas_higgs/', name='atlas_higgs/', size=0, modificationTime=0),
# ...

# %%
df1 = spark.read.csv("dbfs:/databricks-datasets/flights/departuredelays.csv", header ="True")
df1.show()
# Out:
# +--------+-----+--------+------+-----------+
# |    date|delay|distance|origin|destination|
# +--------+-----+--------+------+-----------+
# |01011245|    6|     602|   ABE|        ATL|
# |01020600|   -8|     369|   ABE|        DTW|
# |01021245|   -2|     602|   ABE|        ATL|
# |01020605|   -4|     602|   ABE|        ATL|
# |01031245|   -4|     602|   ABE|        ATL|
# |01030605|    0|     602|   ABE|        ATL|
# |01041243|   10|     602|   ABE|        ATL|
# |01040605|   28|     602|   ABE|        ATL|
# |01051245|   88|     602|   ABE|        ATL|
# |01050605|    9|     602|   ABE|        ATL|
# |01061215|   -6|     602|   ABE|        ATL|
# |01061725|   69|     602|   ABE|        ATL|
# |01061230|    0|     369|   ABE|        DTW|
# |01060625|   -3|     602|   ABE|        ATL|
# |01070600|    0|     369|   ABE|        DTW|
# |01071725|    0|     602|   ABE|        ATL|
# |01071230|    0|     369|   ABE|        DTW|
# |01070625|    0|     602|   ABE|        ATL|
# ...

# %% [markdown]
# ### Challenge 1

# %%
df2 = df1.groupBy('destination').count().toPandas().sort_values('count', ascending=False).head(5)
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>destination</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>170</th>
#       <td>ATL</td>
#       <td>90434</td>
#     </tr>
#     <tr>
#       <th>149</th>
#       <td>DFW</td>
#       <td>66050</td>
#     </tr>
#     <tr>
#       <th>187</th>
#       <td>ORD</td>
#       <td>61967</td>
#     </tr>
#     <tr>
#       <th>227</th>
#       <td>LAX</td>
#       <td>53601</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>DEN</td>
#       <td>50921</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 3))
plt.bar(df2['destination'], df2['count'])
plt.xlabel('Destination')
plt.ylabel('Count')
plt.title('Top 5 Destinations')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# %sh
pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-59c213d1-1a8e-40ca-a360-02b1320fc7be/bin/python -m pip install --upgrade pip' command.

# %%
import seaborn as sns

tips = sns. load_dataset("tips")

tips
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>sex</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.99</td>
#       <td>1.01</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.34</td>
#       <td>1.66</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
sns.set_theme()

sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
# Out[16]: <seaborn.axisgrid.FacetGrid at 0x796c51da0fa0>

# %%
sns. catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker")
# Out:
# Out[17]: <seaborn.axisgrid.FacetGrid at 0x796c2e618460>

# %%
sns. catplot(data=tips, kind="violin", x="day", y="total_bill" , hue="smoker", split=False)
# Out:
# Out[18]: <seaborn.axisgrid.FacetGrid at 0x796c2ddb77f0>

# %%
sns. catplot(data=tips, kind="bar", x="day", y="total_bill" , hue="smoker")
# Out:
# Out[19]: <seaborn.axisgrid.FacetGrid at 0x796c2ddb7fa0>

# %%
dots = sns. load_dataset("dots")
dots
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>align</th>
#       <th>choice</th>
#       <th>time</th>
#       <th>coherence</th>
#       <th>firing_rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>dots</td>
#       <td>T1</td>
#       <td>-80</td>
#       <td>0.0</td>
#       <td>33.189967</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>dots</td>
#       <td>T1</td>
#       <td>-80</td>
#       <td>3.2</td>
#       <td>31.691726</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>dots</td>
#       <td>T1</td>
#       <td>-80</td>
#       <td>6.4</td>
#       <td>34.279840</td>
#     </tr>
#     <tr>
# ...

# %%
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)
# Out:
# Out[21]: <seaborn.axisgrid.FacetGrid at 0x796c5d4f3640>

# %%
penguins = sns. load_dataset ("penguins")
penguins
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>species</th>
#       <th>island</th>
#       <th>bill_length_mm</th>
#       <th>bill_depth_mm</th>
#       <th>flipper_length_mm</th>
#       <th>body_mass_g</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.1</td>
#       <td>18.7</td>
#       <td>181.0</td>
#       <td>3750.0</td>
#       <td>Male</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adelie</td>
#       <td>Torgersen</td>
#       <td>39.5</td>
#       <td>17.4</td>
#       <td>186.0</td>
#       <td>3800.0</td>
# ...

# %%
sns. jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")
# Out:
# Out[23]: <seaborn.axisgrid.JointGrid at 0x796c2e67c370>

# %%
sns.pairplot(data=penguins, hue="species")
# Out:
# Out[24]: <seaborn.axisgrid.PairGrid at 0x796c2d7da1f0>

# %%
df3 = spark.read.csv("dbfs:/databricks-datasets/bikeSharing/data-001/day.csv", header ="True")
df3.show()
# Out:
# +-------+----------+------+---+----+-------+-------+----------+----------+--------+--------+--------+---------+------+----------+----+
# |instant|    dteday|season| yr|mnth|holiday|weekday|workingday|weathersit|    temp|   atemp|     hum|windspeed|casual|registered| cnt|
# +-------+----------+------+---+----+-------+-------+----------+----------+--------+--------+--------+---------+------+----------+----+
# |      1|2011-01-01|     1|  0|   1|      0|      6|         0|         2|0.344167|0.363625|0.805833| 0.160446|   331|       654| 985|
# |      2|2011-01-02|     1|  0|   1|      0|      0|         0|         2|0.363478|0.353739|0.696087| 0.248539|   131|       670| 801|
# |      3|2011-01-03|     1|  0|   1|      0|      1|         1|         1|0.196364|0.189405|0.437273| 0.248309|   120|      1229|1349|
# |      4|2011-01-04|     1|  0|   1|      0|      2|         1|         1|     0.2|0.212122|0.590435| 0.160296|   108|      1454|1562|
# ...

# %%
df3.printSchema()
# Out:
# root
#  |-- instant: string (nullable = true)
#  |-- dteday: string (nullable = true)
#  |-- season: string (nullable = true)
#  |-- yr: string (nullable = true)
#  |-- mnth: string (nullable = true)
#  |-- holiday: string (nullable = true)
#  |-- weekday: string (nullable = true)
#  |-- workingday: string (nullable = true)
#  |-- weathersit: string (nullable = true)
#  |-- temp: string (nullable = true)
#  |-- atemp: string (nullable = true)
#  |-- hum: string (nullable = true)
#  |-- windspeed: string (nullable = true)
#  |-- casual: string (nullable = true)
#  |-- registered: string (nullable = true)
#  |-- cnt: string (nullable = true)

# %% [markdown]
# ### Challenge 2

# %%
bike = df3.toPandas()
bike
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>instant</th>
#       <th>dteday</th>
#       <th>season</th>
#       <th>yr</th>
#       <th>mnth</th>
#       <th>holiday</th>
#       <th>weekday</th>
#       <th>workingday</th>
#       <th>weathersit</th>
#       <th>temp</th>
#       <th>atemp</th>
#       <th>hum</th>
#       <th>windspeed</th>
#       <th>casual</th>
#       <th>registered</th>
#       <th>cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2011-01-01</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0</td>
# ...

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    object
#  1   dteday      731 non-null    object
#  2   season      731 non-null    object
#  3   yr          731 non-null    object
#  4   mnth        731 non-null    object
#  5   holiday     731 non-null    object
#  6   weekday     731 non-null    object
#  7   workingday  731 non-null    object
#  8   weathersit  731 non-null    object
#  9   temp        731 non-null    object
#  10  atemp       731 non-null    object
#  11  hum         731 non-null    object
#  12  windspeed   731 non-null    object
#  13  casual      731 non-null    object
#  14  registered  731 non-null    object
#  15  cnt         731 non-null    object
# dtypes: object(16)
# memory usage: 91.5+ KB

# %%
bike['cnt'] = bike['cnt'].astype(int)
bike['weekday'] = bike['weekday'].astype(int)

# %%
sns.catplot(data=bike, kind="bar", x="weekday", y="cnt")
# Out:
# Out[44]: <seaborn.axisgrid.FacetGrid at 0x796c1ebb3040>

# %% [markdown]
# ### Challenge 3

# %%
sns. catplot(data=bike, kind="bar", x="weekday", y="cnt" , hue="weathersit")
# Out:
# Out[45]: <seaborn.axisgrid.FacetGrid at 0x796c2c688520>

# %% [markdown]
# ### Challenge 4

# %%
sns. catplot(data=bike, kind="violin", x="weekday", y="cnt" , hue="weathersit")
# Out:
# Out[46]: <seaborn.axisgrid.FacetGrid at 0x796c1f1a5280>

# %% [markdown]
# ### Challenge 5

# %%
sns.catplot(data=bike, kind="swarm", x="weekday", y="cnt", hue="weathersit")
# Out:
# Out[47]: <seaborn.axisgrid.FacetGrid at 0x796c51473970>
